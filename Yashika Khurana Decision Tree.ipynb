# %% [markdown]
# # <span style='background :yellow' > AUTHOR: YASHIKA KHURANA </span>

# %% [markdown]
# ## THE SPARKS FOUNDATION

# %% [markdown]
# ## GRIP TASK 6 : Prediction Using Decision Tree Algorithm

# %% [markdown]
# ### AIM: To create a decision tree classifier and visualize it graphically

# %% [markdown]
#  ***
#  ---
#  ___

# %% [markdown]
# ## <span style='color:Blue'> Importing library files  </span>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %% [markdown]
# ## <span style='color:Blue'> Loading dataset </span>

# %%
iris=datasets.load_iris()
x=pd.DataFrame(iris.data, columns=iris.feature_names)

# %% [markdown]
# ## <span style='color:Blue'> Processing data</span>

# %%
x.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y=pd.DataFrame(iris.target,columns=["Species"])

# %%
y
# Out:
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=0)

# %%
x_train.shape
# Out:
# (120, 4)

# %%
y_train.shape
# Out:
# (120, 1)

# %%
x_test.shape
# Out:
# (30, 4)

# %%
y_test.shape
# Out:
# (30, 1)

# %% [markdown]
# ## <span style='color:Blue'> Creating decision trees </span>

# %%
dt= DecisionTreeClassifier() # uses gini

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.predict(x_test)
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0])

# %%
y_test
# Out:
#      Species
# 114        2
# 62         1
# 33         0
# 107        2
# 7          0
# 100        2
# 40         0
# 86         1
# 76         1
# 71         1
# 134        2
# 51         1
# 73         1
# 54         1
# 63         1
# 37         0
# 78         1
# 90         1
# 45         0
# 16         0
# 121        2
# 66         1
# 24         0
# 8          0
# 126        2
# 22         0
# 44         0
# 97         1
# 93         1
# 26         0

# %% [markdown]
# ## <span style='color:Blue'> Evaluating the decision trees </span>

# %%
dt.score(x_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ### Score: 1 (with gini)

# %%
dt2= DecisionTreeClassifier(criterion='entropy',max_depth=5) # uses entropy

# %%
dt2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
dt2.score(x_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ### Score: 1 (with entropy)

# %% [markdown]
# ## <span style='color:Blue'> Predictions on testing data </span>

# %%
Y_pred=dt.predict(x_test)

# %%
Y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0])

# %%
y_test
# Out:
#      Species
# 114        2
# 62         1
# 33         0
# 107        2
# 7          0
# 100        2
# 40         0
# 86         1
# 76         1
# 71         1
# 134        2
# 51         1
# 73         1
# 54         1
# 63         1
# 37         0
# 78         1
# 90         1
# 45         0
# 16         0
# 121        2
# 66         1
# 24         0
# 8          0
# 126        2
# 22         0
# 44         0
# 97         1
# 93         1
# 26         0

# %% [markdown]
# ## <span style='color:Blue'> Visualising decision tree </span>

# %%
from sklearn import tree

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt, 
                   feature_names=iris.feature_names,  
                   class_names=iris.target_names,
                   filled=True)
